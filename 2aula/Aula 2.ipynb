# %%
#file:///usr/share/doc/opencv-doc/html/index.html

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Lendo imagem com padrão OpenCV - Lê como BGR

# %%
img = cv2.imread("../Imgs/pinguim.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


#se for exibir com plt tem que converter de BGR para RGB
plt.imshow(img)

# %%
print(img.shape)
#img
# Out:
# (400, 600, 3)

# %%
#lembrar de itertools

#quantização, apagando bits mais significativos

img = cv2.imread("../Imgs/lenna.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(np.array([[y & 0xef for y in x] for x in img]))
#plt.imshow(img)

# %% [markdown]
# Lendo imagem com padrão Matplotlib

# %%
img2 = plt.imread("../Imgs/lenna.jpg")
plt.imshow(np.array([[y & 0x8f for y in x] for x in img2]))
